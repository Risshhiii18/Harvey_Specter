# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
temp = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv')
temp = temp[:365]

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(temp.Temp, order = (4,1,0)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.Temp   No. Observations:                  364
# Model:                 ARIMA(4, 1, 0)   Log Likelihood                -847.952
# Method:                       css-mle   S.D. of innovations              2.484
# Date:                Sat, 25 Apr 2020   AIC                           1707.903
# Time:                        14:37:20   BIC                           1731.286
# Sample:                             1   HQIC                          1717.197
#
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -0.0074      0.061     -0.121      0.903      -0.127       0.112
# ar.L1.D.Temp    -0.3664      0.051     -7.122      0.000      -0.467      -0.266
# ar.L2.D.Temp    -0.3369      0.054     -6.295      0.000      -0.442      -0.232
# ar.L3.D.Temp    -0.2311      0.054     -4.314      0.000      -0.336      -0.126
# ar.L4.D.Temp    -0.2052      0.051     -3.991      0.000      -0.306      -0.104
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.6000           -1.2864j            1.4195           -0.1805
# AR.2            0.6000           +1.2864j            1.4195            0.1805
# AR.3           -1.1631           -1.0322j            1.5551           -0.3845
# AR.4           -1.1631           +1.0322j            1.5551            0.3845
# -----------------------------------------------------------------------------
# """

# %%
model.plot_predict()

# %%
model.plot_predict(365,379)

# %%
preds, err, conf = model.forecast(15)

# %%
preds
# Out:
# array([16.63273182, 15.77715864, 15.90690241, 15.85765138, 16.17135966,
#        16.20276621, 16.05446775, 16.01997354, 15.9950956 , 16.02782174,
#        16.04677712, 16.02578992, 16.00878937, 15.99514777, 15.99099074])

# %%
plt.plot(preds)
plt.yticks(np.arange(7,26,step = 0.5));
